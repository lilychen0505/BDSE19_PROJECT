# %%
import requests
import pandas as pd
from pprint import pprint
from bs4 import BeautifulSoup

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36',
    'cookie': 'ASP.NET_SessionId=jyoyuzo2zojtn1h2pou4ll5c; _ga=GA1.2.1217753821.1624798144; _gid=GA1.2.1088610507.1624798144; ai_user=f5jVI|2021-06-27T12:49:04.148Z; _gat=1; ai_session=wabZ9|1624878025292|1624879727285.7'}
websites = []
for i in range(1,5): 
    url=f'https://used.carnews.com/UsedCar?PageSize=30&Page={i}' 
    r=requests.get(url,headers=headers)
    soup=BeautifulSoup(r.text,'lxml')
    car_info=soup.find_all(class_='uc-tool-container')
    for i in car_info[:30]:
        websites.append(i.button.get('data-compare-id'))

# %%
websites
# Out:
# ['267503',
#  '267279',
#  '214849',
#  '269608',
#  '271595',
#  '264052',
#  '271390',
#  '171705',
#  '269978',
#  '272157',
#  '271141',
#  '271143',
#  '271144',
#  '271150',
#  '271151',
#  '272117',
#  '272116',
#  '272114',
#  '270921',
#  '271231',
#  '268382',
#  '253344',
#  '265126',
#  '270143',
#  '270261',
#  '268152',
#  '268295',
#  '270849',
#  '267255',
#  '272019',
#  '267115',
#  '264652',
#  '269772',
#  '265016',
#  '271918',
#  '262046',
#  '271861',
#  '269691',
#  '271858',
#  '267882',
#  '266983',
#  '266915',
#  '271790',
#  '262136',
#  '271780',
#  '247640',
#  '269508',
#  '266927',
#  '266625',
#  '266835',
#  '266474',
#  '266532',
#  '266569',
#  '271686',
#  '269290',
#  '260567',
#  '258098',
#  '269347',
#  '269463',
#  '257569',
#  '271580',
#  '269427',
#  '271558',
#  '271548',
#  '270388',
#  '271511',
#  '264285',
#  '271418',
#  '269254',
#  '269058',
#  '269029',
#  '269162',
#  '271381',
#  '270320',
#  '270325',
#  '270486',
#  '270487',
#  '271006',
#  '271275',
#  '271274',
#  '268734',
#  '268848',
#  '269996',
#  '269997',
#  '263395',
#  '271160',
#  '266541',
#  '271101',
#  '271099',
#  '271098',
#  '268736',
#  '268739',
#  '268804',
#  '270914',
#  '270906',
#  '268459',
#  '243149',
#  '249737',
#  '270741',
#  '265653',
#  '263616',
#  '267714',
#  '270201',
#  '270199',
#  '269861',
#  '225507',
#  '215549',
#  '254676',
#  '271889',
#  '270625',
#  '269451',
#  '220281',
#  '185042',
#  '272201',
#  '269241',
#  '269559',
#  '272200',
#  '272197',
#  '272195',
#  '272194']

# %%
#Second Step: Get the detail of the cars
df_detail_basic=pd.DataFrame(columns=['id', '車款', '車型', '年份', '里程','車輛價格', '縣市', '顏色','車門數','座位數', '排氣量','驅動方式','燃料','變速系統','刊登標題','照片網址','車商名','車商地址'])
# df_equipements=pd.DataFrame(columns=['皮椅','晶片系統','恆溫空調','VCD','ABS','CD','電動窗','中控鎖','電動後視鏡','天窗','霧燈','DVD','倒車顯影','衛星導航','TCS防滑','防盜','安全氣囊','定速','一手車','電動座椅','核桃木飾板','4WD','倒車雷達','行車電腦','總代理','MP3','柴油','ＨＩＤ頭燈','鋁圈'])
df1 = []
df3 = []
a = ''

    for j in websites: 
        url=f'https://used.carnews.com/UsedCar/Details/{j}' 
        r=requests.get(url,headers=headers)
        soup=BeautifulSoup(r.text,'lxml')
        if soup.find_all(class_="uc-car-detail") == None:
            websites跳下一個

        # id=j
   
        # 車款
        car_brand1 = soup.find(class_='uc-breadcrumb')
        car_brand2 = car_brand1.find_all('li')
        car_brand3 = car_brand2[2]
        car_brand = car_brand3.find('a').text.strip()

        #車型 
    
        car_brand4 = car_brand2[3]
        car_model1 = car_brand4.find('a').text.strip()
        car_brand5 = car_brand2[4]
        car_model2 = car_brand5.find('a').text.strip()
        car_model = car_model1 + ' ' + car_model2
        # 車身型式 car_body


        # 車輛年份
        detail_year = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_year1 = detail_year.find_all('tr')
        detail_year2 = detail_year1[0]
        detail_year3 = detail_year2.find_all('td')
        car_year = detail_year3[1].text.strip()
 
        # 里程
        detail_basic1 = soup.find(class_='pure-u-2-3 uc-basic-info')
        detail_basic2 = detail_basic1.find_all('td')
        car_mileage = detail_basic2[3].text.strip()
    
        # 車輛價格
        car_price = soup.find(class_='price').text.strip()

        # 車輛(商)所在地
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[2]
        detail_city3 = detail_city2.find_all('td')
        car_address = detail_city3[1].text.strip() 
    
        # 車輛顏色
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[1]
        detail_city3 = detail_city2.find_all('td')
        car_color = detail_city3[1].text.strip()    
    
        # 車門數
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[3]
        detail_city3 = detail_city2.find_all('td')
        car_door = detail_city3[3].text.strip()
    
        # 座位數
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[3]
        detail_city3 = detail_city2.find_all('td')
        car_seat = detail_city3[1].text.strip()
        # 排氣量
        detail_basic1 = soup.find(class_='pure-u-2-3 uc-basic-info')
        detail_basic3 = detail_basic1.find_all('tr')
        detail_basic4 = detail_basic3[1]
        detail_basic5 = detail_basic4.find_all('td')
        car_cylinderVolume = detail_basic5[3].text.strip()

        # 汽缸數(或形式)
    
        # 驅動方式
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[5]
        detail_city3 = detail_city2.find_all('td')
        car_driveMode = detail_city3[1].text.strip()
        # 燃料
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[4]
        detail_city3 = detail_city2.find_all('td')
        car_fuel = detail_city3[1].text.strip()
        # 變速系統
        detail_city = soup.find(class_='uc-car-detailspec uc-tab-content uc-card-container')
        detail_city1 = detail_city.find_all('tr')
        detail_city2 = detail_city1[4]
        detail_city3 = detail_city2.find_all('td')
        car_gear = detail_city3[3].text.strip()
        # 刊登標題
        car_title = soup.find('span',class_='uc-card-title').text.strip()
        # 照片網址
        car_img = soup.find(class_='uc-gallery-carousel')
        car_photo = car_img.find('img')['src']

        # 車商id
    
        # 車商名
        dealer_name = soup.find('h3',class_='uc-title').text.strip()
        # 賣家身份
    
        # 車商地址
        addr = soup.find_all('div',class_='uc-panel-content')
        addr1 = addr[1]
        addr2 = addr1.find_all('dl')
        addr3 = addr2[0]
        dealer_address = addr3.find('dd').text.strip()

        # 是否有認證

    
        df1.append([j,car_brand,car_model,car_year,car_mileage,car_price,car_address,car_color,car_door,car_seat,car_cylinderVolume,car_driveMode,car_fuel,car_gear,car_title,car_photo,dealer_name,dealer_address])
df2 = pd.DataFrame(df1,columns=df_detail_basic.columns)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-46043b1174c2> in <module>
#      17         car_brand1 = soup.find(class_='uc-breadcrumb')
#      18         car_brand2 = car_brand1.find_all('li')
# ---> 19         car_brand3 = car_brand2[2]
#      20         car_brand = car_brand3.find('a').text.strip()
#      21
#
# IndexError: list index out of range

# %%
aaaa = soup.find_all(class_="uc-car-detail")
aaaa
# Out:
# []

# %%
a = ''
a
# Out:
# ''

# %%
j
# Out:
# '269861'

# %%
df2 = pd.DataFrame(df1,columns=df_detail_basic.columns)

# %%
df1
# Out:
# [['267503',
#   'MINI',
#   'Cooper S Countryman 1.6',
#   '2016',
#   '18120 公里',
#   '103.8萬',
#   '台北市',
#   '紅色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   'MINI COUNTRYMAN S 不mini的MINI 2016年 益誠汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-b7958db7-374a-4cda-830c-e126d4000d4f.jpg?w=600&h=450',
#   '益誠汽車',
#   '台北市中山區民族東路560號'],
#  ['267279',
#   'Benz',
#   'C-Class Coupe C63S',
#   '2018',
#   '30416 公里',
#   '348萬',
#   '新北市',
#   '白色',
#   '2 門',
#   '4 人座',
#   '4000cc',
#   '後輪驅動',
#   '汽油車',
#   '自手排',
#   '●龍德國際● BENZ AMG C63s COUPE 性能跑車座椅加持 ~',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-0ddb9f62-7277-45d0-9edf-604fd0efd901.jpg?w=600&h=450',
#   '龍德國際貿易有限公司',
#   '新北市泰山區新北大道7段20-22號'],
#  ['214849',
#   'BMW',
#   '3 Series 323',
#   '2006',
#   '110039 公里',
#   '32.8萬',
#   '新北市五股區',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2500cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '現正優惠中喜歡都可談 日規 正Ｍ版 天窗 車況極新 認證車 原鈑件 里程保證',
#   'https://usedcar-image-v2.azurewebsites.net//Storages/car-images-original/temp-39981dfa-055c-465d-9150-b90ba29a453d.JPG?w=600&h=450',
#   '祐昌汽車',
#   '新北市五股區四維路28號'],
#  ['269608',
#   'PORSCHE',
#   'Cayenne 3.0',
#   '2018',
#   '33950 公里',
#   '279萬',
#   '台北市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'PORSCHE CAYENNE E3 3.0 斯圖加特精湛工藝 2018年 益誠',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-fd54f00b-6a2b-4478-a6e4-bb08a9a05c89.jpg?w=600&h=450',
#   '益誠汽車',
#   '台北市中山區民族東路560號'],
#  ['271595',
#   'Benz',
#   'B-Class B180',
#   '2019',
#   '30206 公里',
#   '128萬',
#   '台北市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1400cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   'Benz B180 你好賓士都會安全實用 2019年 益誠汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5fc7af7a-7b10-409a-af68-e05923cfb5b3.jpg?w=600&h=450',
#   '益誠汽車',
#   '台北市中山區民族東路560號'],
#  ['264052',
#   'FORD',
#   'Mustang 2.3',
#   '2018',
#   '60673 公里',
#   '129.8萬',
#   '台北市',
#   '黑色',
#   '2 門',
#   '4 人座',
#   '2300cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   'Ford Mustang 2.3t 駿馬奔馳美型MAN敞篷 2018年 益誠',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-bc9b535d-740b-4f16-82a0-9aed08adf436.jpg?w=600&h=450',
#   '益誠汽車',
#   '台北市中山區民族東路560號'],
#  ['271390',
#   'LUXGEN',
#   'U6 1.8',
#   '2017',
#   '34954 公里',
#   '46.8萬',
#   '台南市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1800cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '台南昱翼汽車 2017年 那智捷 U6 頂級 一手原版件',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ebda1733-b56c-406e-a930-2740e73a56b9.jpg?w=600&h=450',
#   '昱翼汽車',
#   '台南市仁德區中山路99號'],
#  ['171705',
#   'CITROEN',
#   'C2 1.6',
#   '2005',
#   '158120 公里',
#   '面議',
#   '台北市',
#   '紅色',
#   '2 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '銓富-CITROEN C2 1.6 2005 熱血自手排',
#   'https://usedcar-image-v2.azurewebsites.net//Storages/car-images-original/temp-1462c845-b2e3-40af-9dd4-771bbbc99855.JPG?w=600&h=450',
#   '銓富汽車國際',
#   '台北市北投區承德路六段483號'],
#  ['269978',
#   'SUBARU',
#   'Outback 2.5',
#   '2017',
#   '86655 公里',
#   '69.8萬',
#   '桃園市',
#   '鐵灰色',
#   '5 門',
#   '5 人座',
#   '2500cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '剛柔並濟i-S頂級AWD水平對臥*跨界旅行車*全原廠紀錄少跑.新車價對折入主OK',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-608b4d93-13d4-4bd5-95f8-73ca4fcaa971.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['272157',
#   'Benz',
#   'B-Class B180',
#   '2018',
#   '6822 公里',
#   '112.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '【鋐基汽車】M-Benz B180 AMG總代理低里程 CARPLAY雙電動椅',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-2d355da0-7c06-453c-b0aa-58ac81d07556.jpg?w=600&h=450',
#   '鋐基汽車',
#   '高雄市鼓山區中華一路912-1號'],
#  ['271141',
#   'BMW',
#   '2 Series 218i',
#   '2018',
#   '38950 公里',
#   '86.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2017年218i 都會版 一手車 全車原版件 原廠保養 里程保證',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-f0256da9-74ec-4ea3-86c9-24b5aecd7c16.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['271143',
#   'MINI',
#   'Cooper Countryman 1.5',
#   '2018',
#   '17495 公里',
#   '117.8萬',
#   '高雄市',
#   '灰色',
#   '5 門',
#   '5 人座',
#   '1500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2018年 MINI COUNTRYMAN 1.5T 一手女用車 原版件低里程',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-44e21399-c8dc-44c4-acb4-1d5875788d6d.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['271144',
#   'BMW',
#   '2 Series 218d',
#   '2015',
#   '102787 公里',
#   '63.8萬',
#   '高雄市',
#   '藍色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '柴油車',
#   '手自排',
#   '2014 BMW 218D 全車原版件 一手車 里程保證',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-740a4123-3b05-4369-b5df-6fda43e210a6.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['271150',
#   'FORD',
#   'Focus 1.6',
#   '2015',
#   '33625 公里',
#   '32.8萬',
#   '高雄市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '2015年 FOCUS 1.6 5D 低里程 優惠時尚流行車款',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-37821159-bfa9-4057-9ea4-7422ea98517f.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['271151',
#   'Benz',
#   'E-Class E300',
#   '2019',
#   '18297 公里',
#   '238.8萬',
#   '高雄市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2019年 E300 AMG 總代理 一手女用車 低里程 配備齊全',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ab2002f8-5a8b-4bca-af74-1bdbfd4fb760.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['272117',
#   'TOYOTA',
#   'RAV-4 2.0',
#   '2015',
#   '51900 公里',
#   '59.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2015年豐田 RAV4 2.0 E-HI 原版件 里程保證 一手女用車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-998691fc-f6e0-4f47-bb67-e2a969c712c1.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['272116',
#   'HYUNDAI',
#   'ix35 2.0',
#   '2016',
#   '75525 公里',
#   '43.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2016年IX35 2.0 豪華型 CP值高 休旅車 原版件 里程保證',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-7be36814-d9b9-422e-a5e9-c4032a9fcd15.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['272114',
#   'BMW',
#   '3 Series 320',
#   '2012',
#   '43787 公里',
#   '75.8萬',
#   '高雄市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2012年BMW 320I SPORT版 原版件 一手車 原廠保養',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-78f6d4b9-d5bd-4ec5-974b-4b9346aab164.JPG?w=600&h=450',
#   '傑霖汽車',
#   '高雄市仁武區鳳仁路5號之12'],
#  ['270921',
#   'Benz',
#   'C-Class C43 AMG',
#   '2016',
#   '72948 公里',
#   '199萬',
#   '桃園市',
#   '白色',
#   '2 門',
#   '4 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '禮遇佳車業 x C43 Coupe x 總代理 x 賽車座椅',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-6fceab78-e64d-4706-a5fd-c4f8980c4e8b.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['271231',
#   'BMW',
#   '1 Series 118',
#   '2012',
#   '96976 公里',
#   '58.8萬',
#   '桃園市',
#   '灰色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '後輪驅動',
#   '汽油車',
#   '自手排',
#   '禮遇佳車業 x BMW 118i x  F20 x 漂亮車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-227a760c-1959-432f-9177-30c63ad3d972.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['268382',
#   'Benz',
#   'C-Class C450',
#   '2016',
#   '37229 公里',
#   '178.8萬',
#   '桃園市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'C450 AMG 4Matic 23P跟車 超頂配 #4703',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-9a864df2-60cd-40f3-8d83-96ff87cd07ee.jpg?w=600&h=450',
#   '老船長車庫',
#   '桃園市桃園區永安路1189號'],
#  ['253344',
#   'HONDA',
#   'Civic 1.8',
#   '2008',
#   '171190 公里',
#   '23.8萬',
#   '新北市',
#   '藍色',
#   '4 門',
#   '5 人座',
#   '1800cc',
#   '前輪驅動',
#   '汽油車',
#   '自排',
#   '實車實價 一手車 頂級 天窗 恆溫 換檔撥鍵 HID',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ac2a511f-8542-4720-a4d7-629489fb6e8a.JPG?w=600&h=450',
#   '冠典汽車',
#   '新北市汐止區大同路一段1號'],
#  ['265126',
#   'HYUNDAI',
#   'ix35 2.4',
#   '2014',
#   '75278 公里',
#   '45.9萬',
#   '桃園市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2400cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '同級車最便宜!頂級2.4全景天窗S版.影音滿配.里程跑少.直售不二價.超高CP值',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-b289c93d-05fe-4332-85a0-2a054b702606.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['270143',
#   'Benz',
#   'GLS-Class GLS 350d',
#   '2017',
#   '80352 公里',
#   '面議',
#   '台北市',
#   '棕色',
#   '5 門',
#   '7 人座',
#   '3000cc',
#   '四輪驅動',
#   '柴油車',
#   '手自排',
#   '2017年 總代理 BENZ GLS350d 4MATIC 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-71cdb79c-b14f-4f31-a2ca-881bdad5f416.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['270261',
#   'Benz',
#   'GL-Class GL350',
#   '2016',
#   '71079 公里',
#   '175萬',
#   '台北市',
#   '灰色',
#   '5 門',
#   '7 人座',
#   '3000cc',
#   '四輪驅動',
#   '柴油車',
#   '手自排',
#   '2016年 總代理 BENZ GL350d AMG 4MATIC 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-69c1f53d-b1ba-46f4-a756-1930f87230e4.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['268152',
#   'Benz',
#   'GLE-Class 3.5',
#   '2017',
#   '56353 公里',
#   '168萬',
#   '台北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '柴油車',
#   '手自排',
#   '2017年 總代理 BENZ GLE 350d 4MATIC 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-904a4854-e4b8-449b-ab49-7355ccc87236.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['268295',
#   'Benz',
#   'S-Class S400 3.0',
#   '2014',
#   '44554 公里',
#   '178萬',
#   '台北市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '3000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2014年總代理BENZ S400 L傳奇饗宴 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-02353312-3cf9-4f06-ad4c-c99cf7f30143.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['270849',
#   'Benz',
#   'GLA-Class GLA180',
#   '2018',
#   '79191 公里',
#   '面議',
#   '台北市',
#   '灰色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2018年 總代理 BNEZ GLA180 AMG 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-c7ed2f04-cb4d-44ca-ad05-f0b7265c8a7b.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['267255',
#   'PORSCHE',
#   'Cayenne 3.0',
#   '2019',
#   '32604 公里',
#   '289萬',
#   '台北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '2018 年 總代理 PORSCHE CAYENNE 3.0 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ed27763f-ccd1-4d7e-a90d-35c057553490.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['272019',
#   'Benz',
#   'C-Class C300',
#   '2017',
#   '50125 公里',
#   '148萬',
#   '台中市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   'C300 AMG 2017 全景 盲點 柏林之音 LED頭燈 電尾門 寶瑪國際',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5af05838-1f4e-4e5b-b520-46071d62fbba.jpg?w=600&h=450',
#   '寶瑪國際汽車',
#   '台中市北屯區崇德路三段539-1號'],
#  ['267115',
#   'SKODA',
#   'Fabia 1.0 TSI',
#   '2019',
#   '13873 公里',
#   '58.8萬',
#   '高雄市',
#   '紅色',
#   '5 門',
#   '5 人座',
#   '1000cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '2019年 SKODA FABIA 1.0L 原廠保固至2023年/免費保養兩次',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-cff275a2-9519-432c-b97d-ae7cbd61da3e.JPG?w=600&h=450',
#   '乙鈞汽車',
#   '高雄市左營區自由四路428號'],
#  ['264652',
#   'Benz',
#   'GLC-Class GLC 250',
#   '2016',
#   '70985 公里',
#   '163萬',
#   '台北市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '2016 總代理 BENZ GLC250 AMG 4MATIC 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-6e23f140-bb69-4396-9677-9e67a301448b.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['269772',
#   'Benz',
#   'GLE-Class 350',
#   '2016',
#   '48701 公里',
#   '178萬',
#   '台北市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '柴油車',
#   '手自排',
#   '2016年 總代理 BENZ GLE350d  LUX 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-cc106d76-b36d-4203-a5b1-cd4d3c84fe0b.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['265016',
#   'MAZDA',
#   'CX-5 2.2',
#   '2017',
#   '77786 公里',
#   '69.5萬',
#   '桃園市',
#   '紅色',
#   '5 門',
#   '5 人座',
#   '2200cc',
#   '四輪驅動',
#   '柴油車',
#   '手自排',
#   '5折入手柴油最頂級AWD選配魂動紅新車約140萬.原廠記錄終身保固.超優值選擇~',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-a1cbf6db-3581-4059-93d8-a6ca14573163.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['271918',
#   'Benz',
#   'A-Class A250',
#   '2019',
#   '20381 公里',
#   '面議',
#   '台北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2019 年 總代理 BENZ A250 AMG 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-46bdf998-876a-4755-843b-a1492ab8abe1.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['262046',
#   'BMW',
#   '5 Series 530',
#   '2017',
#   '56866 公里',
#   '166萬',
#   '屏東縣',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '正17盲點5AS天窗HK環景HUD車道偏移行人及追撞橫向來車警示手勢控制導航無線',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-e883f559-95e4-4425-94f8-c0ff58f88372.jpg?w=600&h=450',
#   '中懋汽車',
#   '屏東縣屏東市和生路二段509-3號'],
#  ['271861',
#   'HONDA',
#   'HR-V 1.8',
#   '2018',
#   '39773 公里',
#   '65.8萬',
#   '桃園市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1800cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '禮遇佳車業 x HRV S x  選配大包 x 一手車 x 全原廠保養',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-367f60d4-8c8d-4f62-a523-1eb07531c585.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['269691',
#   'VOLVO',
#   'XC90 2.4',
#   '2013',
#   '65656 公里',
#   '89.8萬',
#   '桃園市',
#   '棕色',
#   '5 門',
#   '7 人座',
#   '2400cc',
#   '四輪驅動',
#   '柴油車',
#   '手自排',
#   '新車要價300萬 硬派安全7人座休旅 里程才跑6萬 原廠紀錄 多項耗材更新完成!',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ad0ba65d-99fa-4b03-acab-79b3ed15d699.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['271858',
#   'LEXUS',
#   'RX Series RX300',
#   '2018',
#   '35580 公里',
#   '169.8萬',
#   '台南市',
#   '棕色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   'Hybrid 混合動力車',
#   '手自排',
#   '總代理/自動跟車/360度環景/抬頭顯示/無線充電/10向電動調整椅 #3921',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-921b99f0-3c5f-423e-9db8-fbb865f0aecc.JPG?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['267882',
#   'MAZDA',
#   '2 1.5',
#   '2011',
#   '164125 公里',
#   '23萬',
#   '新竹市',
#   '鐵灰色',
#   '5 門',
#   '5 人座',
#   '1500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2011年式 馬自達2 MAZDA 2 保證一手車 原廠保養',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-b4cd4f5a-5dcf-43f1-a116-ce01e10f3609.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['266983',
#   'VW',
#   'Golf 1.2',
#   '2015',
#   '85732 公里',
#   '49.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1200cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '【鋐基汽車】VW GOLF 1.2 TSI TL',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-86aad529-cbb6-4f9a-bee4-623eb1245d88.jpg?w=600&h=450',
#   '鋐基汽車',
#   '高雄市鼓山區中華一路912-1號'],
#  ['266915',
#   'BMW',
#   '1 Series 118',
#   '2017',
#   '91955 公里',
#   '79.8萬',
#   '高雄市',
#   '灰色',
#   '5 門',
#   '5 人座',
#   '1500cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '【鋐基汽車】 BMW 118i F20 小改款 總代理2017',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-fce82ce2-5ed7-4c01-966f-688c57e0ea83.jpg?w=600&h=450',
#   '鋐基汽車',
#   '高雄市鼓山區中華一路912-1號'],
#  ['271790',
#   'TOYOTA',
#   'C-HR 1.2',
#   '2017',
#   '72141 公里',
#   '68.8萬',
#   '台南市',
#   '銀色',
#   '5 門',
#   '5 人座',
#   '1200cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '1.2L渦輪跨界休旅車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ba61f9c7-e797-4555-acef-055c9e7064b9.jpg?w=600&h=450',
#   '銨銡汽車',
#   '台南市安南區安吉路一段212號'],
#  ['262136',
#   'BMW',
#   '1 Series 118',
#   '2011',
#   '84216 公里',
#   '45.8萬',
#   '新北市',
#   '鐵灰色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '大信SAVE 2011年 BMW 118i 實跑8萬KM 里程保證 手自排TCS',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-e3d535f2-613f-495b-921a-10cde092518a.JPG?w=600&h=450',
#   '大信汽車-SAVE認證車聯盟',
#   '新北市泰山區新北大道5段618號'],
#  ['271780',
#   'TOYOTA',
#   'Yaris 1.5',
#   '2017',
#   '52789 公里',
#   '面議',
#   '台南市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '五門掀背小車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-8a25f89c-7e89-4348-acc7-07b2a0f09ed0.jpg?w=600&h=450',
#   '銨銡汽車',
#   '台南市安南區安吉路一段212號'],
#  ['247640',
#   'MAZDA',
#   '5 七人座',
#   '2009',
#   '214628 公里',
#   '29.8萬',
#   '台中市',
#   '灰色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2009年 MAZDA5 七人座 後排螢幕 影音 導航 倒車顯影',
#   'https://usedcar-image-v2.azurewebsites.net//Storages/car-images-original/temp-548c4b41-e9ac-4afc-8856-8097fe64a219.jpg?w=600&h=450',
#   '雄大汽車/台中/中古車/二手車/網友推薦/中部網路大賣場',
#   '台中市大肚區山陽村沙田路三段591巷11-1號'],
#  ['269508',
#   'BMW',
#   '3 Series Touring 320',
#   '2011',
#   '86536 公里',
#   '68萬',
#   '台北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '柴油車',
#   '自手排',
#   '2011年BMW 320d Touring 一手車新車至今全程原廠保養',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-9c3dc8b4-f3c2-49c2-a214-ad6091448819.JPG?w=600&h=450',
#   '炎禾汽車',
#   '台北市中山區民族東路554號'],
#  ['266927',
#   'Benz',
#   'CLA-Class CLA250',
#   '2020',
#   '1263 公里',
#   '199.8萬',
#   '台南市',
#   '鐵灰色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '全新車CLA250 AMG 跑一千 倒攝 盲點 全景 加熱記憶椅 CarPlay',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-98a35a84-52a5-44cf-bd8b-d32a06bc8673.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['266625',
#   'Benz',
#   'C-Class C300',
#   '2017',
#   '43203 公里',
#   '163.8萬',
#   '台南市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'AMG 23P 跟車系統 環景 盲點 全景 加熱記憶椅 摸門解鎖 電尾#0349',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-564d6219-0a1f-471d-ac2a-3463de009f46.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['266835',
#   'Benz',
#   'GLC-Class GLC 300',
#   '2020',
#   '29106 公里',
#   '246.8萬',
#   '台南市',
#   '藍色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'GLC300 COUPE AMG 免鑰匙 倒攝 盲點 加熱記憶椅 天窗 感應尾門',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-b6d7f645-4e60-44b8-ac86-7b166c3a4304.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['266474',
#   'Benz',
#   'GLA-Class GLA250',
#   '2017',
#   '34898 公里',
#   '136.8萬',
#   '台南市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'GLA250 AMG 免鑰匙 H/K 倒攝盲點 全景 CarPlay 加熱記憶椅',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-987d6fac-82a5-4b3c-8fa1-749f964953bc.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['266532',
#   'BMW',
#   '4 Series Gran Coupe 428i',
#   '2016',
#   '57502 公里',
#   '133.8萬',
#   '台南市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '428xi SportLine 免鑰匙 電尾門 定速 前後加熱椅 記憶椅 天窗',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-67f7d6c8-a131-4c41-bd03-07be0fb777f5.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['266569',
#   'BMW',
#   '3 Series 328',
#   '2016',
#   '49792 公里',
#   '126.8萬',
#   '台南市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '328xi M-Sport 免鑰匙 加熱記憶椅 倒攝 定速 LED轉向頭燈 天窗',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-35f66a71-344f-47c6-b5ec-4700e6117644.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['271686',
#   'Benz',
#   'CLA-Class CLA250',
#   '2017',
#   '47250 公里',
#   '面議',
#   '高雄市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '勝億汽車 2017 BENZ CLA250 AMG',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-1627565d-4726-4d10-ab19-616e007f321b.jpg?w=600&h=450',
#   '勝億汽車',
#   '高雄市鳥松區中正路367之33號'],
#  ['269290',
#   'Benz',
#   'GLC-Class GLC 300',
#   '2017',
#   '67581 公里',
#   '面議',
#   '台中市',
#   '鐵灰色',
#   '0 門',
#   '0 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '2017 Benz GLC300 AMG',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-cc4d2c4e-ddce-48a1-862d-07d16226daba.jpg?w=600&h=450',
#   '大豪貿易車業',
#   '台中市南屯區環中路四段395號'],
#  ['260567',
#   'Benz',
#   'A-Class A250',
#   '2019',
#   '10364 公里',
#   '面議',
#   '台中市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '2019 A250 AMG#0028',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-7101438d-4c42-4f7e-b4c1-7764525c52a9.jpg?w=600&h=450',
#   '大豪貿易車業',
#   '台中市南屯區環中路四段395號'],
#  ['258098',
#   'Benz',
#   'A-Class A250',
#   '2019',
#   '5136 公里',
#   '面議',
#   '台中市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '2019-BENZ A250 AMG 4-MATIC ＃3230',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-9617125a-55d7-4de1-97fd-4a5f54f4eb7f.jpg?w=600&h=450',
#   '大豪貿易車業',
#   '台中市南屯區環中路四段395號'],
#  ['269347',
#   'BMW',
#   '5 Series 530',
#   '2017',
#   '26370 公里',
#   '面議',
#   '台中市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '【超多】BMW 530i 現車12台',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-f0a3b0a3-3e8c-47fd-a9aa-cd556aff956f.jpg?w=600&h=450',
#   '大豪貿易車業',
#   '台中市南屯區環中路四段395號'],
#  ['269463',
#   'MAZDA',
#   '6 2.5',
#   '2021',
#   '33244 公里',
#   '109.9萬',
#   '桃園市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '疫情期間共體時艱 現金直售入主品味旅行白馬6~最頂2.5旗艦進化版 新車原廠保固',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-1a522f3d-bc7c-4f74-93c0-14d04d7bcb4a.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['257569',
#   'BMW',
#   'X5 Series X5 xDrive',
#   '2019',
#   '18350 公里',
#   '308萬',
#   '新北市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '2019 X5 xDrive40i M-Sport選配破百萬吉美汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-8683a8f7-6aef-4d1c-8468-26d45b455fd0.jpg?w=600&h=450',
#   '吉美國際汽車有限公司',
#   '新北市土城區中央路三段76巷14號'],
#  ['271580',
#   'MAZDA',
#   '3 1.6',
#   '2014',
#   '51743 公里',
#   '34.8萬',
#   '高雄市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '1600cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '【鋐基汽車】 MAZDA 3 1.6 頂級型 4D 2014',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-7e0e7fcc-6dea-4f74-b27a-cd3d4e52f11d.jpg?w=600&h=450',
#   '鋐基汽車',
#   '高雄市鼓山區中華一路912-1號'],
#  ['269427',
#   'VOLVO',
#   'V40 1.5',
#   '2020',
#   '19335 公里',
#   '99.9萬',
#   '桃園市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '新款迷人小鋼炮1.5T3版.ACC自動跟車+高安全性.僅開1萬保固中.省落地價差',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-da67da02-88ed-465e-9126-aaf8e08ea602.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['271558',
#   'BMW',
#   '3 Series 328',
#   '2013',
#   '139879 公里',
#   '面議',
#   '台南市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '國產車價、高CP直、安全、帥氣，M-SPORT套件直上~',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-e623052f-9fe0-4987-840e-9d69789f6696.jpg?w=600&h=450',
#   '立翔汽車',
#   '台南市安南區海佃路2段423號'],
#  ['271548',
#   'LAND ROVER',
#   'Velar 3.0',
#   '2020',
#   '5901 公里',
#   '面議',
#   '台北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '2020年 總代理 LAND ROVER VELAR P250 S 昇益汽車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-b91cb74c-a4e9-44fc-9861-f45926f01bad.jpg?w=600&h=450',
#   '昇益汽車',
#   '台北市北投區承德路六段335號'],
#  ['270388',
#   'TOYOTA',
#   'Sienna 3.5',
#   '2019',
#   '44794 公里',
#   '156.8萬',
#   '新北市',
#   '白色',
#   '5 門',
#   '8 人座',
#   '3500cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   '2019年 選配免鑰匙 盲點 自動跟車 車道偏移 電動滑門 認證車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5580f671-97dc-4329-9b9a-3582a13ebe88.jpg?w=600&h=450',
#   '祐昌汽車',
#   '新北市五股區四維路28號'],
#  ['271511',
#   'Benz',
#   'S-Class S350',
#   '2008',
#   '158923 公里',
#   '38.8萬',
#   '桃園市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '3500cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '禮遇佳車業 x S350L x  車況超棉 x 商務車 x 家用車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ceed5e4a-ae96-4d56-93af-76511c521c15.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['264285',
#   'BENTLEY',
#   'Continental 6.0',
#   '2007',
#   '82492 公里',
#   '168萬',
#   '台北市',
#   '黑色',
#   '2 門',
#   '4 人座',
#   '6000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'BENTLEY CONTINENTAL GT W12奢華的享受 2007 益誠',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-58b98cbc-2e16-4666-91cf-0c9d65fa30c8.jpg?w=600&h=450',
#   '益誠汽車',
#   '台北市中山區民族東路560號'],
#  ['271418',
#   'BMW',
#   '3 Series 320',
#   '2020',
#   '63983 公里',
#   '面議',
#   '桃園市',
#   '藍色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2020 BMW G20 320i M-Sport 首發版 總代理 [德義汽車]',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-78aae40e-5e42-4133-9dc3-863b04d843fe.jpeg?w=600&h=450',
#   '德義汽車',
#   '桃園市蘆竹區文中路一段92號'],
#  ['269254',
#   'TOYOTA',
#   'Previa 3.5',
#   '2008',
#   '147691 公里',
#   '43.5萬',
#   '新北市',
#   '棕色',
#   '5 門',
#   '7 人座',
#   '3500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '大信SAVE 2008年式 PREVIA 最頂級 極低里程 原廠保養 實車實價!',
#   'https://usedcar-image-v2.azurewebsites.net//Storages/car-images-original/temp-553c908e-bdbb-4c87-a983-fad6b3b14603.JPG?w=600&h=450',
#   '大信汽車-SAVE認證車聯盟',
#   '新北市泰山區新北大道5段618號'],
#  ['269058',
#   'MAZDA',
#   '5 七人座',
#   '2012',
#   '151196 公里',
#   '38.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '7 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2012 Mazda5 胎壓偵測 定速巡航 電動天窗',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-3325b589-31cc-4e09-b98a-a60a570de97f.JPG?w=600&h=450',
#   '合益汽車',
#   '高雄市鳥松區中正路46-55號'],
#  ['269029',
#   'VW',
#   'Golf 1.6',
#   '2013',
#   '82942 公里',
#   '32萬',
#   '新竹市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2013年式 福斯 VW GOLF 僅跑8萬公里',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-24bf41a0-82b7-4a2c-9f46-45612cb230b0.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['269162',
#   'VW',
#   'Golf 1.4',
#   '2011',
#   '136241 公里',
#   '33.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1400cc',
#   '前輪驅動',
#   '汽油車',
#   '自手排',
#   'VW GOLF 1.4 TSI (雙增壓）總代理',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-606e90b8-c54d-4ed1-8ba1-73a294eac6dd.jpg?w=600&h=450',
#   '鋐基汽車',
#   '高雄市鼓山區中華一路912-1號'],
#  ['271381',
#   'SUBARU',
#   'XV 2.0',
#   '2019',
#   '16022 公里',
#   '79.8萬',
#   '桃園市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '東洋跨界跑旅.頂級版.四輪傳動.新車110萬里程才1萬.原廠紀錄.現買現省.全貸',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-6c8bc376-7fca-4d0e-925d-4469803534f1.jpg?w=600&h=450',
#   '桃園SUM模範店首福汽車',
#   '桃園市中壢區新中北路二段68號'],
#  ['270320',
#   'LEXUS',
#   'IS Series IS200T',
#   '2016',
#   '81325 公里',
#   '103.8萬',
#   '桃園市',
#   '綠色',
#   '0 門',
#   '0 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '禮遇佳車業 x IS200t F-Sport x 原鈑件 x 原廠保養 x 實車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-e99791fc-2f98-4e44-a132-8ceb7917c5cb.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['270325',
#   'Benz',
#   'CLA-Class CLA45 AMG',
#   '2013',
#   '76068 公里',
#   '129萬',
#   '桃園市',
#   '灰色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '禮遇佳車業 x CLA45 AMG x 水泥灰 x 新款方向盤 x 實車實價',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-65cdf04e-80a3-4ee4-9c3b-ef4805426a81.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['270486',
#   'FORD',
#   'Mondeo 2.0',
#   '2018',
#   '68655 公里',
#   '93.8萬',
#   '桃園市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '禮遇佳車業 x MONDEO WAGON x 一手車 x 稀有車款 x 實車在店',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-8fbc368b-f562-4cf8-ba02-e6ee4046e27e.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['270487',
#   'AUDI',
#   'A4 2.0',
#   '2016',
#   '52440 公里',
#   '119萬',
#   '桃園市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '禮遇佳車業 x A4 45TFSI x S-Line套件 x 四輪傳動 x 一手',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5d68df64-2989-4cea-be25-e539fd983795.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['271006',
#   'MASERATI',
#   'Levante 3.0',
#   '2016',
#   '71579 公里',
#   '210萬',
#   '桃園市',
#   '藍色',
#   '5 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '禮遇佳車業 x Maserati x 總代理 x Levante',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-f33a8980-1a5f-4c2d-b45e-1625ceed9efe.jpg?w=600&h=450',
#   '禮遇佳車業',
#   '桃園市龜山區復興一路471號'],
#  ['271275',
#   'PORSCHE',
#   'Macan 2.0',
#   '2018',
#   '45038 公里',
#   '面議',
#   '台中市',
#   '藍色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自排',
#   '2018年 Porsche Macan #09673',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-428f5787-285e-4aab-a798-2fc4453e47fc.jpg?w=600&h=450',
#   '大豪貿易車業',
#   '台中市南屯區環中路四段395號'],
#  ['271274',
#   'ALFA ROMEO',
#   'Stelvio 2.0T',
#   '2018',
#   '51777 公里',
#   '面議',
#   '台中市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '2018 Alfa Romeo Stelvio Ti Sport Q4',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-48053b1a-c30c-45bb-bd52-c2fbbd4771b6.jpg?w=600&h=450',
#   '大豪貿易車業',
#   '台中市南屯區環中路四段395號'],
#  ['268734',
#   'MINI',
#   'Cooper Countryman 1.6',
#   '2016',
#   '70264 公里',
#   '89.8萬',
#   '高雄市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '【鋐基汽車】 MINI COUNTRYMAN COOPER R60總代理',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-e042b53e-c25a-41ba-a3de-8d2b9c3a89ad.jpg?w=600&h=450',
#   '鋐基汽車',
#   '高雄市鼓山區中華一路912-1號'],
#  ['268848',
#   'Benz',
#   'GLA-Class GLA180',
#   '2018',
#   '31049 公里',
#   '136.8萬',
#   '桃園市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2018 BENZ GLA180 AMG 末代小改款 #0246',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ebd9098b-6d30-412e-a2c3-5f9aebcf0964.jpg?w=600&h=450',
#   '老船長車庫',
#   '桃園市桃園區永安路1189號'],
#  ['269996',
#   'MAZDA',
#   '3 2.0',
#   '2018',
#   '53858 公里',
#   '72萬',
#   '新竹市',
#   '紅色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2018年式 馬自達 3 MAZDA 3 旗艦型 BOSE音響',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-a9c04c64-6785-4fe2-b8b7-2aef83e78a93.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['269997',
#   'MAZDA',
#   '6 2.0',
#   '2015',
#   '64647 公里',
#   '已收訂',
#   '新竹市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2015年 馬自達 6 MAZDA 6 汽油版頂級旗艦款 超美低里程',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-7171a3b5-1597-42eb-a474-567e41e3fe5f.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['263395',
#   'BMW',
#   '1 Series 120',
#   '2018',
#   '80472 公里',
#   '100萬',
#   '新竹市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2018年式 BMW 120i M-SPORT 紀念款 汎德總代理',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5a768b30-bfa0-44fe-bc82-74bb7169d6cb.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['271160',
#   'TOYOTA',
#   'Alphard 3.5',
#   '2017',
#   '118920 公里',
#   '189.8萬',
#   '台南市',
#   '黑色',
#   '5 門',
#   '7 人座',
#   '3500cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   'ALPHARD 七人豪華座 雙天窗 分區空調 電動椅 影音系統 商務首選',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-471a2508-51c6-4384-82c1-e9c942e94604.JPG?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['266541',
#   'VW',
#   'Golf 2.0',
#   '2008',
#   '132781 公里',
#   '18.8萬',
#   '新北市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '柴油車',
#   '手自排',
#   '大信SAVE 2008 GOLF 2.0 TDI 柴油 渦輪 動態穩定 MK5',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-210785df-851f-49eb-b82e-0c8fc9a25eec.JPG?w=600&h=450',
#   '大信汽車-SAVE認證車聯盟',
#   '新北市泰山區新北大道5段618號'],
#  ['271101',
#   'Benz',
#   'E-Class E200 K',
#   '2007',
#   '156320 公里',
#   '已收訂',
#   '新竹市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '1800cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2007年式 BENZ E200K 末代小改款經典好車',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-41535e72-90f3-41c7-892e-c38325597fed.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['271099',
#   'BMW',
#   '3 Series 318',
#   '2005',
#   '223191 公里',
#   '19萬',
#   '新竹市',
#   '銀色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2005年 汎德總代理 BMW 318 M-SPORT 2.0',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-f4eeb91c-a5a5-4c8a-b0c2-a08ee5053c89.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['271098',
#   'Benz',
#   'CLA-Class CLA250',
#   '2015',
#   '74800 公里',
#   '102萬',
#   '新竹市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2016年領 BENZ CLA250 AMG版',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-d76cd311-903e-453b-9dad-58512beab743.JPG?w=600&h=450',
#   '宏展汽車',
#   '新竹市東區東區經國路一段209號'],
#  ['268736',
#   'Benz',
#   'GLC-Class GLC 300',
#   '2018',
#   '19529 公里',
#   '221.8萬',
#   '台南市',
#   '白色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   'GLC300 Coupe 23P 跟車系統 環景 盲點 雙加熱記憶椅 免鑰匙摸門',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ed5b4963-6059-496d-9f52-dc4c80ba1227.JPG?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['268739',
#   'PORSCHE',
#   'Macan 2.0',
#   '2020',
#   '18782 公里',
#   '283.8萬',
#   '台南市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '紅內裝 BOSE 14向通風記憶椅 前後雷達 盲點 全景 免鑰匙 #1453',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5ab562f5-118b-43cd-95aa-635fb65245bd.JPG?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['268804',
#   'Benz',
#   'CLA-Class CLA250',
#   '2017',
#   '82699 公里',
#   '136.8萬',
#   '台南市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   'CLA250 AMG雷電版 夜色 全景 carplay 盲點 免鑰匙 加熱記憶椅',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-2935d22e-11b6-4226-b1d5-f2e55105e78c.jpg?w=600&h=450',
#   '鼎翔汽車',
#   '台南市永康區中華路1028號'],
#  ['270914',
#   'NISSAN',
#   'Livina 1.6',
#   '2015',
#   '59593 公里',
#   '33.8萬',
#   '高雄市',
#   '銀色',
#   '5 門',
#   '5 人座',
#   '1600cc',
#   '前輪驅動',
#   '汽油車',
#   '自排',
#   '2015 LIVINA 豪華版 原鈑件 低里程 認證車 都會輕休旅',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-3a3d77a7-1e33-47e6-8c43-51d886ded4dd.jpg?w=600&h=450',
#   '合益汽車',
#   '高雄市鳥松區中正路46-55號'],
#  ['270906',
#   'MINI',
#   'Cooper S Countryman 2.0',
#   '2018',
#   '32317 公里',
#   '159.8萬',
#   '台北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '2018總代理Mini Countryman JCW ALL4 一手車全原廠保養',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-9dffc11b-f60d-4def-a5c0-d977c4aa32a6.JPG?w=600&h=450',
#   '炎禾汽車',
#   '台北市中山區民族東路554號'],
#  ['268459',
#   'Benz',
#   'C-Class C300',
#   '2015',
#   '87872 公里',
#   '118.8萬',
#   '台北市',
#   '黑色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '2015 賓士 C300 柏林之音 Keyless 大螢幕 全景天窗 盲點',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-8d4addfb-9ad4-45d2-999f-7331a95bf0d9.jpg?w=600&h=450',
#   '東晴國際車業',
#   '台北市內湖區堤頂大道二段285號'],
#  ['243149',
#   'VW',
#   'T5 2.0',
#   '2013',
#   '201415 公里',
#   '59.8萬',
#   '台中市',
#   '銀色',
#   '4 門',
#   '9 人座',
#   '2000cc',
#   '前輪驅動',
#   '柴油車',
#   '手排',
#   '2012年 T5 六速手排 140匹 九人座',
#   'https://usedcar-image-v2.azurewebsites.net//Storages/car-images-original/temp-ae83156c-fcfa-4e73-bfe5-f7543cd2bb53.jpg?w=600&h=450',
#   '雄大汽車/台中/中古車/二手車/網友推薦/中部網路大賣場',
#   '台中市大肚區山陽村沙田路三段591巷11-1號'],
#  ['249737',
#   'MAZDA',
#   '5 七人座',
#   '2015',
#   '103445 公里',
#   '59.8萬',
#   '台中市',
#   '白色',
#   '5 門',
#   '7 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '2015年 MAZDA 5  七人座 頂級款 電動滑門',
#   'https://usedcar-image-v2.azurewebsites.net/Storages/car-images-original/temp-172a4d4d-56ca-4aae-b3a3-4bc8a8f5f72f.jpg?w=600&h=450',
#   '雄大汽車/台中/中古車/二手車/網友推薦/中部網路大賣場',
#   '台中市大肚區山陽村沙田路三段591巷11-1號'],
#  ['270741',
#   'BMW',
#   '3 Series 318',
#   '2014',
#   '0 公里',
#   '78.8萬',
#   '台北市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '2000cc',
#   '後輪驅動',
#   '柴油車',
#   '手自排',
#   '銓富-寶馬 318D 柴油 省油 又省稅 CP值高',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-9aa0a020-65ac-4db1-93d4-6a3d5612fea1.jpg?w=600&h=450',
#   '銓富汽車國際',
#   '台北市北投區承德路六段483號'],
#  ['265653',
#   'Benz',
#   'GLC-Class 43',
#   '2017',
#   '81975 公里',
#   '235萬',
#   '台北市',
#   '白色',
#   '4 門',
#   '5 人座',
#   '3000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '銓富-GLC43 AMG 氣氛燈 360度環景夜色套件 雙魚眼 電尾門含腳踢感應',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-ac8357ee-2e48-435f-b937-b34ded908653.jpg?w=600&h=450',
#   '銓富汽車國際',
#   '台北市北投區承德路六段483號'],
#  ['263616',
#   'BMW',
#   'M6 M6 Coupe',
#   '2006',
#   '99226 公里',
#   '98萬',
#   '台北市',
#   '其他',
#   '2 門',
#   '4 人座',
#   '4300cc',
#   '四輪驅動',
#   '汽油車',
#   '自手排',
#   '銓富-BMW M6 (E63) 2006',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-52aab894-6f94-4234-940f-f2f080cf0380.jpg?w=600&h=450',
#   '銓富汽車國際',
#   '台北市北投區承德路六段483號'],
#  ['267714',
#   'BENTLEY',
#   'Continental 6.0',
#   '2006',
#   '104831 公里',
#   '168萬',
#   '台北市',
#   '黑色',
#   '2 門',
#   '4 人座',
#   '6000cc',
#   '四輪驅動',
#   '汽油車',
#   '手自排',
#   '銓富-賓利 皇家Bentley Continental GT (1代) 2006',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-9c86ec7e-3f6c-4ff1-b07a-bebf12183ba5.jpg?w=600&h=450',
#   '銓富汽車國際',
#   '台北市北投區承德路六段483號'],
#  ['270201',
#   'BMW',
#   '3 Series Coupe 335',
#   '2007',
#   '150859 公里',
#   '45.8萬',
#   '新北市',
#   '白色',
#   '2 門',
#   '4 人座',
#   '3000cc',
#   '後輪驅動',
#   '汽油車',
#   '手自排',
#   '✈美麗信✈ ↘影音賞車在下面↙ 原廠機油冷卻器 免鑰匙摸門解鎖 I-Drive',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-079eefe2-2de5-400b-95d2-9b6090cdef9e.JPG?w=600&h=450',
#   '美麗信汽車',
#   '新北市三重區河邊北街136號'],
#  ['270199',
#   'Benz',
#   'B-Class B200',
#   '2007',
#   '129609 公里',
#   '35.8萬',
#   '新北市',
#   '黑色',
#   '5 門',
#   '5 人座',
#   '2000cc',
#   '前輪驅動',
#   '汽油車',
#   '手自排',
#   '✈美麗信✈ 總代理特仕車 全車正BRABUS精品 變速箱保固中 可全貸',
#   'https://usedcar-img.azureedge.net/Storages/car-images-original/temp-5a0d515e-374e-470e-893e-b38ab99a0eb7.JPG?w=600&h=450',
#   '美麗信汽車',
#   '新北市三重區河邊北街136號']]

# %%
df2
# Out:
#          id       車款                       車型    年份         里程    車輛價格  \
# 0    267503     MINI  Cooper S Countryman 1.6  2016   18120 公里  103.8萬
# 1    267279     Benz       C-Class Coupe C63S  2018   30416 公里    348萬
# 2    214849      BMW             3 Series 323  2006  110039 公里   32.8萬
# 3    269608  PORSCHE              Cayenne 3.0  2018   33950 公里    279萬
# 4    271595     Benz             B-Class B180  2019   30206 公里    128萬
# ..      ...      ...                      ...   ...        ...     ...
# 99   265653     Benz             GLC-Class 43  2017   81975 公里    235萬
# 100  263616      BMW              M6 M6 Coupe  2006   99226 公里     98萬
# 101  267714  BENTLEY          Continental 6.0  2006  104831 公里    168萬
# 102  270201      BMW       3 Series Coupe 335  2007  150859 公里   45.8萬
# 103  270199     Benz             B-Class B200  2007  129609 公里   35.8萬
#
#          縣市  顏色  車門數   座位數     排氣量  驅動方式   燃料 變速系統  \
# 0       台北市  紅色  5 門  5 人座  1600cc  前輪驅動  汽油車  手自排
# 1       新北市  白色  2 門  4 人座  4000cc  後輪驅動  汽油車  自手排
# 2    新北市五股區  黑色  4 門  5 人座  2500cc  後輪驅動  汽油車  手自排
# 3       台北市  白色  5 門  5 人座  3000cc  四輪驅動  汽油車  手自排
# 4       台北市  白色  5 門  5 人座  1400cc  前輪驅動  汽油車  手自排
# ..      ...  ..  ...   ...     ...   ...  ...  ...
# 99      台北市  白色  4 門  5 人座  3000cc  四輪驅動  汽油車  手自排
# 100     台北市  其他  2 門  4 人座  4300cc  四輪驅動  汽油車  自手排
# 101     台北市  黑色  2 門  4 人座  6000cc  四輪驅動  汽油車  手自排
# 102     新北市  白色  2 門  4 人座  3000cc  後輪驅動  汽油車  手自排
# 103     新北市  黑色  5 門  5 人座  2000cc  前輪驅動  汽油車  手自排
#
#                                          刊登標題  \
# 0     MINI COUNTRYMAN S 不mini的MINI 2016年 益誠汽車
# 1       ●龍德國際● BENZ AMG C63s COUPE 性能跑車座椅加持 ~
# 2      現正優惠中喜歡都可談 日規 正Ｍ版 天窗 車況極新 認證車 原鈑件 里程保證
# 3    PORSCHE CAYENNE E3 3.0 斯圖加特精湛工藝 2018年 益誠
# 4             Benz B180 你好賓士都會安全實用 2019年 益誠汽車
# ..                                        ...
# 99   銓富-GLC43 AMG 氣氛燈 360度環景夜色套件 雙魚眼 電尾門含腳踢感應
# 100                      銓富-BMW M6 (E63) 2006
# 101  銓富-賓利 皇家Bentley Continental GT (1代) 2006
# 102   ✈美麗信✈ ↘影音賞車在下面↙ 原廠機油冷卻器 免鑰匙摸門解鎖 I-Drive
# 103       ✈美麗信✈ 總代理特仕車 全車正BRABUS精品 變速箱保固中 可全貸
#
#                                                   照片網址         車商名  \
# 0    https://usedcar-img.azureedge.net/Storages/car...        益誠汽車
# 1    https://usedcar-img.azureedge.net/Storages/car...  龍德國際貿易有限公司
# 2    https://usedcar-image-v2.azurewebsites.net//St...        祐昌汽車
# 3    https://usedcar-img.azureedge.net/Storages/car...        益誠汽車
# 4    https://usedcar-img.azureedge.net/Storages/car...        益誠汽車
# ..                                                 ...         ...
# 99   https://usedcar-img.azureedge.net/Storages/car...      銓富汽車國際
# 100  https://usedcar-img.azureedge.net/Storages/car...      銓富汽車國際
# 101  https://usedcar-img.azureedge.net/Storages/car...      銓富汽車國際
# 102  https://usedcar-img.azureedge.net/Storages/car...       美麗信汽車
# 103  https://usedcar-img.azureedge.net/Storages/car...       美麗信汽車
#
#                    車商地址
# 0        台北市中山區民族東路560號
# 1    新北市泰山區新北大道7段20-22號
# 2          新北市五股區四維路28號
# 3        台北市中山區民族東路560號
# 4        台北市中山區民族東路560號
# ..                  ...
# 99      台北市北投區承德路六段483號
# 100     台北市北投區承德路六段483號
# 101     台北市北投區承德路六段483號
# 102      新北市三重區河邊北街136號
# 103      新北市三重區河邊北街136號
#
# [104 rows x 18 columns]

# %%
# Out:
# <div class="uc-car-detailspec uc-tab-content uc-card-container" id="uc-car-detail-tab-1">
# <section class="uc-card-content">
# <h3 class="hide">詳細資料</h3>
# <section>
# <h4>本車資訊</h4>
# <table>
# <tr>
# <td>車輛年式</td>
# <td>2017</td>
# <td>領牌年月</td>
# <td>
# 2017年
# 7月                                    </td>
# </tr>
# <tr>
# <td>外觀顏色</td>
# <td>灰色</td>
# <td>內裝顏色</td>
# <td>黑色</td>
# </tr>
# <tr>
# <td>車輛所在地</td>
# <td>高雄市</td>
# <td>牌照狀態</td>
# <td>停用註銷</td>
# </tr>
# </table>
# </section>
# <section>
# <h4>本車規格</h4>
# <table>
# <tr>
# <td>乘客數</td>
# <td>5 人座</td>
# <td>車門數</td>
# <td>5 門</td>
# </tr>
# <tr>
# <td>引擎燃料</td>
# <td>汽油車</td>
# <td>變速系統</td>
# <td>手自排</td>
# </tr>
# <tr>
# <td>驅動方式</td>
# <td>後輪驅動</td>
# </tr>
# </table>
# </section>
# <section>
# <h4>安全配備</h4>
# <div class="uc-car-specs pure-g">
# <span class="uc-label pure-u-1-6">安全氣囊</span>
# <span class="uc-label pure-u-1-6">倒車顯影</span>
# <span class="uc-label pure-u-1-6">ABS</span>
# <span class="uc-label pure-u-1-6">LED燈</span>
# <span class="uc-label pure-u-1-6">倒車雷達</span>
# <span class="uc-label pure-u-1-6">防滑循跡</span>
# <span class="uc-label pure-u-1-6">胎壓偵測</span>
# <span class="uc-label pure-u-1-6">動態穩定</span>
# <span class="uc-label pure-u-1-6">上坡起步輔助</span>
# <span class="uc-label pure-u-1-6">自動煞停</span>
# </div>
# </section>
# <section>
# <h4>內裝配備</h4>
# <div class="uc-car-specs pure-g">
# <span class="uc-label pure-u-1-6">DVD</span>
# <span class="uc-label pure-u-1-6">智慧i-key</span>
# <span class="uc-label pure-u-1-6">電動椅</span>
# <span class="uc-label pure-u-1-6">衛星導航GPS</span>
# <span class="uc-label pure-u-1-6">大螢幕</span>
# <span class="uc-label pure-u-1-6">定速</span>
# <span class="uc-label pure-u-1-6">旅程電腦</span>
# <span class="uc-label pure-u-1-6">方向盤快撥鍵</span>
# <span class="uc-label pure-u-1-6">電動伺服方向盤</span>
# <span class="uc-label pure-u-1-6">皮椅</span>
# <span class="uc-label pure-u-1-6">MP3</span>
# <span class="uc-label pure-u-1-6">CD</span>
# <span class="uc-label pure-u-1-6">電子恆溫</span>
# <span class="uc-label pure-u-1-6">KEY-LESSGO免持</span>
# </div>
# </section>
# <section>
# <h4>外觀配備</h4>
# <div class="uc-car-specs pure-g">
# <span class="uc-label pure-u-1-6">電折後視鏡</span>
# <span class="uc-label pure-u-1-6">鋁圈</span>
# </div>
# </section>
# <section>
# <h4>其他配備</h4>
# <div class="uc-car-specs pure-g">
# <span class="uc-label pure-u-1-6">渦輪增壓</span>
# </div>
# </section>
# <section>
# <h4>保證項目</h4>
# <div class="uc-car-specs pure-g">
# <span class="uc-label pure-u-1-6">里程保證</span>
# <span class="uc-label pure-u-1-6">實車</span>
# <span class="uc-label pure-u-1-6">鑑定書</span>
# <span class="uc-label pure-u-1-6">非泡水車</span>
# <span class="uc-label pure-u-1-6">非營業車</span>
# <span class="uc-label pure-u-1-6">非贓車</span>
# <span class="uc-label pure-u-1-6">非失竊尋回車</span>
# <span class="uc-label pure-u-1-6">原鈑件</span>
# <span class="uc-label pure-u-1-6">實價</span>
# <span class="uc-label pure-u-1-6">非重大事故車</span>
# <span class="uc-label pure-u-1-6">總代理</span>
# </div>
# </section>
# </section>
# </div>
